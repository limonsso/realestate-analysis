# %%
import lib.eda as eda
import pandas as pd
import numpy as np
import missingno as msno
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import KNNImputer, IterativeImputer

# %% [markdown]
# ### Récupération des données des propriétées
#
# Nous avions deux tables ou se trouvent données extraites dépuis des pages web.
# **Propriétés**

# %%
from lib.db import read_mongodb_to_dataframe

## Recuperations de toutes les données à partir de la bd
properties_db = read_mongodb_to_dataframe('real_estate_db', 'properties', no_id=False)
properties_details_db = read_mongodb_to_dataframe('real_estate_db', 'properties_details', no_id=False)

# %%
properties_db.head(5)
# Out:
#         _id                     add_date  \
# 0  13363515  2152.0  2022-03-06 00:00:00
# 1  25761492     NaN  2024-07-12 00:00:00
# 2  20417145     NaN  2024-08-22 00:00:00
# 3  23726086     NaN  2024-08-15 00:00:00
# 4  18532646     NaN  2024-07-07 00:00:00
#
#                                              address  \
# 0  {'street': '6926 - 6928, Avenue  Somerled', 'l...
# 1  {'street': '1657, Rue Riendeau', 'locality': '...
# 2  {'street': '1384, Rue de Niverville', 'localit...
# 3  {'street': '952, Rue Chaumont', 'locality': 'C...
# 4  {'street': '1646, Rue Napoléon-Bisson', 'local...
#
#                                              city  company  \
# 0  Montréal (Côte-des-Neiges/Notre-Dame-de-Grâce)  Centris
# 1                                         Chambly  Centris
# 2                                         Chambly  Centris
# 3                                         Chambly  Centris
# 4                                         Chambly  Centris
#
#                                          description  \
# 0  Duplex à vendre à Montréal (Côte-des-Neiges/No...
# 1  Maison à vendre à Chambly, Montérégie, 1657, R...
# 2  Condo à vendre à Chambly, Montérégie, 1384, Ru...
# 3  Maison à vendre à Chambly, Montérégie, 952, Ru...
# 4  Maison à vendre à Chambly, Montérégie, 1646, R...
#
#                                              img_src  \
# 0  https://mspublic.centris.ca/media.ashx?id=ADDD...
# 1  https://mspublic.centris.ca/media.ashx?id=ADDD...
# 2  https://mspublic.centris.ca/media.ashx?id=ADDD...
# 3  https://mspublic.centris.ca/media.ashx?id=ADDD...
# 4  https://mspublic.centris.ca/media.ashx?id=ADDD...
#
#                                                 link  \
# 0  https://www.centris.ca/fr/duplex~a-vendre~mont...
# 1  https://www.centris.ca/fr/maison~a-vendre~cham...
# 2  https://www.centris.ca/fr/condo~a-vendre~chamb...
# 3  https://www.centris.ca/fr/maison~a-vendre~cham...
# 4  https://www.centris.ca/fr/maison~a-vendre~cham...
#
#                  plex-revenue  ...  nbr_chanbres nbr_sal_bain nbr_sal_deau  \
# 0  Rev. bruts pot. : 26 100 $  ...           NaN          NaN          NaN
# 1                         NaN  ...           NaN          NaN          NaN
# 2                         NaN  ...           NaN          NaN          NaN
# 3                         NaN  ...           NaN          NaN          NaN
# 4                         NaN  ...           NaN          NaN          NaN
#
#   parking  prix_evaluation  revenus_annuels_bruts  style  superficie  taxes  \
# 0     NaN              NaN                    NaN    NaN         NaN    NaN
# 1     NaN              NaN                    NaN    NaN         NaN    NaN
# 2     NaN              NaN                    NaN    NaN         NaN    NaN
# 3     NaN              NaN                    NaN    NaN         NaN    NaN
# 4     NaN              NaN                    NaN    NaN         NaN    NaN
#
#    geolocation
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 42 columns]

# %%
properties_details_db.head(5)
# Out:
#         _id                                        description  \
# 0  19205127  C'est ici que vos recherches s'arrêtent!!! Vot...
# 1  16846441  Duplex, vous êtes un investisseur ou vous voul...
# 2  18535427  Pour investisseur. Duplex dont un logement 4 1...
# 3  24303612  Superbe Quadruplex bien situé. Idéal pour inve...
# 4  19680893  Maison à vendre à Charlesbourg. Charmante prop...
#
#                                               images  \
# 0  [https://mspublic.centris.ca/media.ashx?id=ADD...
# 1  [https://mspublic.centris.ca/media.ashx?id=ADD...
# 2  [https://mspublic.centris.ca/media.ashx?id=ADD...
# 3  [https://mspublic.centris.ca/media.ashx?id=ADD...
# 4  [https://mspublic.centris.ca/media.ashx?id=ADD...
#
#                                                  geo annee superficie  \
# 0  {'latitude': '46.9833982700', 'longitude': '-7...  2014  29 620 pc
# 1  {'latitude': '46.8426920000', 'longitude': '-7...  1968   9 647 pc
# 2  {'latitude': '46.2267203100', 'longitude': '-7...  1958   3 455 pc
# 3  {'latitude': '45.2048700000', 'longitude': '-7...  1935   4 715 pc
# 4  {'latitude': '46.8790530000', 'longitude': '-7...  1974        NaN
#
#                       parking revenus_annuels_bruts  \
# 0                   Allée (2)              24 600 $
# 1                   Allée (5)              21 300 $
# 2                   Allée (5)              11 760 $
# 3                         NaN              23 880 $
# 4  Abri d'auto (1), Allée (6)              34 560 $
#
#                                            taxes  \
# 0    {'municipales': '3590', 'scolaires': '267'}
# 1   {'municipales': '3 158', 'scolaires': '243'}
# 2    {'municipales': '1 641', 'scolaires': '68'}
# 3   {'municipales': '3 981', 'scolaires': '183'}
# 4  {'municipales': '2804 ', 'scolaires': '252 '}
#
#                                               unites  ... nbr_chanbres  \
# 0                                                NaN  ...          NaN
# 1  [{'unite': '4 ½', 'nb_unite': '1 '}, {'unite':...  ...          NaN
# 2                                                NaN  ...          NaN
# 3  [{'unite': '3 ½', 'nb_unite': '2 '}, {'unite':...  ...          NaN
# 4  [{'unite': '1 ½', 'nb_unite': '3 '}, {'unite':...  ...          NaN
#
#   nbr_sal_bain  nbr_sal_deau  prix_evaluation  style address link  \
# 0          NaN           NaN              NaN    NaN     NaN  NaN
# 1          NaN           NaN              NaN    NaN     NaN  NaN
# 2          NaN           NaN              NaN    NaN     NaN  NaN
# 3          NaN           NaN              NaN    NaN     NaN  NaN
# 4          NaN           NaN              NaN    NaN     NaN  NaN
#
#   nbr_bathroom nbr_bedroom vendue
# 0          NaN         NaN    NaN
# 1          NaN         NaN    NaN
# 2          NaN         NaN    NaN
# 3          NaN         NaN    NaN
# 4          NaN         NaN    NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Statistiques descriptives

# %%
properties_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111514 entries, 0 to 111513
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   _id                    111514 non-null  int64
#  1                          1 non-null       float64
#  2   add_date               111514 non-null  object
#  3   address                111514 non-null  object
#  4   city                   111514 non-null  object
#  5   company                111514 non-null  object
#  6   description            111514 non-null  object
#  7   img_src                84593 non-null   object
#  8   link                   111514 non-null  object
#  9   plex-revenue           16151 non-null   object
#  10  price                  111514 non-null  float64
#  11  type                   101335 non-null  object
#  12  update_at              111514 non-null  object
#  13  vendue                 111110 non-null  object
#  14  revenu                 18252 non-null   float64
#  15  surface                85384 non-null   float64
#  16  longitude              110766 non-null  float64
#  17  latitude               110766 non-null  float64
#  18  construction_year      82477 non-null   float64
#  19  municipal_taxes        42212 non-null   float64
#  20  school_taxes           41902 non-null   float64
#  21  unites                 66366 non-null   object
#  22  depenses               3599 non-null    float64
#  23  price_assessment       18541 non-null   float64
#  24  nb_bathroom            52103 non-null   object
#  25  nb_bedroom             51810 non-null   object
#  26  plex-revenu            5827 non-null    object
#  27  version                58686 non-null   object
#  28  region                 46930 non-null   object
#  29  annee                  1 non-null       object
#  30  geo                    1 non-null       object
#  31  images                 1 non-null       object
#  32  nbr_chanbres           1 non-null       float64
#  33  nbr_sal_bain           1 non-null       float64
#  34  nbr_sal_deau           0 non-null       float64
#  35  parking                0 non-null       float64
#  36  prix_evaluation        1 non-null       object
#  37  revenus_annuels_bruts  0 non-null       float64
#  38  style                  1 non-null       object
#  39  superficie             1 non-null       object
#  40  taxes                  1 non-null       object
#  41  geolocation            2 non-null       object
# dtypes: float64(16), int64(1), object(25)
# memory usage: 35.7+ MB

# %%
properties_details_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118848 entries, 0 to 118847
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   _id                    118848 non-null  object
#  1   description            113390 non-null  object
#  2   images                 118848 non-null  object
#  3   geo                    118848 non-null  object
#  4   annee                  92140 non-null   object
#  5   superficie             88232 non-null   object
#  6   parking                64086 non-null   object
#  7   revenus_annuels_bruts  16987 non-null   object
#  8   taxes                  106977 non-null  object
#  9   unites                 94019 non-null   object
#  10  created_at             25582 non-null   object
#  11  depenses               26773 non-null   object
#  12  nbr_chanbres           56485 non-null   float64
#  13  nbr_sal_bain           54167 non-null   float64
#  14  nbr_sal_deau           19952 non-null   float64
#  15  prix_evaluation        77320 non-null   object
#  16  style                  52795 non-null   object
#  17  address                45455 non-null   object
#  18  link                   76732 non-null   object
#  19  nbr_bathroom           13831 non-null   object
#  20  nbr_bedroom            13858 non-null   object
#  21  vendue                 47948 non-null   object
# dtypes: float64(3), object(19)
# memory usage: 19.9+ MB

# %% [markdown]
# ### Selection des variables

# %%
cols_selected = ['_id', 'add_date', 'city', 'description', 'longitude', 'latitude','price', 'type', 'municipal_taxes', 'school_taxes','construction_year','surface','region', 'vendue','nb_bedroom','nb_bathroom']

# %%
df_properties = properties_db[cols_selected].copy()

# %%
df_properties.head(10)
# Out:
#         _id             add_date  \
# 0  13363515  2022-03-06 00:00:00
# 1  25761492  2024-07-12 00:00:00
# 2  20417145  2024-08-22 00:00:00
# 3  23726086  2024-08-15 00:00:00
# 4  18532646  2024-07-07 00:00:00
# 5  16700867  2024-08-22 00:00:00
# 6  21678408  2024-08-19 00:00:00
# 7  13544392  2024-07-12 00:00:00
# 8   9862041  2024-07-24 00:00:00
# 9  11692802  2024-07-27 00:00:00
#
#                                              city  \
# 0  Montréal (Côte-des-Neiges/Notre-Dame-de-Grâce)
# 1                                         Chambly
# 2                                         Chambly
# 3                                         Chambly
# 4                                         Chambly
# 5                                         Chambly
# 6                                         Chambly
# 7                                         Chambly
# 8                                         Chambly
# 9                                         Chambly
#
#                                          description  longitude   latitude  \
# 0  Duplex à vendre à Montréal (Côte-des-Neiges/No...        NaN        NaN
# 1  Maison à vendre à Chambly, Montérégie, 1657, R... -73.292301  45.430607
# 2  Condo à vendre à Chambly, Montérégie, 1384, Ru... -73.297033  45.432642
# 3  Maison à vendre à Chambly, Montérégie, 952, Ru... -73.287130  45.442001
# 4  Maison à vendre à Chambly, Montérégie, 1646, R... -73.322884  45.434597
# 5  Maison à vendre à Chambly, Montérégie, 5, Rue ... -73.292063  45.457826
# 6  Maison à vendre à Chambly, Montérégie, 1285, A... -73.306337  45.446623
# 7  Maison à vendre à Chambly, Montérégie, 1372, R... -73.290873  45.438721
# 8  Maison à vendre à Chambly, Montérégie, 1791, A... -73.281452  45.448023
# 9  Maison à vendre à Chambly, Montérégie, 45, Rue... -73.269396  45.443781
#
#       price    type  municipal_taxes  school_taxes  construction_year  \
# 0  749000.0  Duplex              NaN           NaN                NaN
# 1  574900.0  Maison           2930.0         339.0             1991.0
# 2  448800.0   Condo           2285.0         274.0             2013.0
# 3  519900.0  Maison              NaN           NaN             1963.0
# 4  848500.0  Maison           5013.0         634.0             2019.0
# 5  925000.0  Maison              NaN           NaN             1981.0
# 6  659000.0  Maison           2647.0         308.0             2013.0
# 7  599000.0  Maison              NaN           NaN             1964.0
# 8  839800.0  Maison              NaN           NaN             1956.0
# 9  774900.0  Maison           4009.0         373.0             1974.0
#
#    surface region vendue nb_bedroom nb_bathroom
# 0      NaN    NaN   True        NaN         NaN
# 1      NaN    NaN   True        NaN         NaN
# 2   1266.0    NaN   True        NaN         NaN
# 3      NaN    NaN   True        NaN         NaN
# 4   3922.0    NaN   True        NaN         NaN
# 5  19059.0    NaN   True          4           2
# 6      NaN    NaN   True        NaN         NaN
# 7   6027.0    NaN   True        NaN         NaN
# 8      NaN    NaN   True        NaN         NaN
# 9      NaN    NaN   True        NaN         NaN

# %% [markdown]
# ### Retypage des variables

# %%
df_properties.dtypes
# Out:
# _id                    int64
# add_date              object
# city                  object
# description           object
# longitude            float64
# latitude             float64
# price                float64
# type                  object
# municipal_taxes      float64
# school_taxes         float64
# construction_year    float64
# surface              float64
# region                object
# vendue                object
# nb_bedroom            object
# nb_bathroom           object
# dtype: object

# %%
df_properties['add_date'] = pd.to_datetime(df_properties['add_date'],errors='coerce')

# %%
df_properties.dtypes
# Out:
# _id                           int64
# add_date             datetime64[ns]
# city                         object
# description                  object
# longitude                   float64
# latitude                    float64
# price                       float64
# type                         object
# municipal_taxes             float64
# school_taxes                float64
# construction_year           float64
# surface                     float64
# region                       object
# vendue                       object
# nb_bedroom                   object
# nb_bathroom                  object
# dtype: object

# %% [markdown]
# ### Élimination des doublons

# %%
df_properties['_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Visualisation des valeurs manquantes

# %%
msno.matrix(df_properties)
# Out:
# <Axes: >

# %%
msno.bar(df_properties)
# Out:
# <Axes: >

# %% [markdown]
# ### Matrice de correalacion

# %%
msno.heatmap(df_properties)
# Out:
# <Axes: >

# %% [markdown]
# ### Corrélation entre les valeurs manquantes

# %%
msno.dendrogram(df_properties)
# Out:
# <Axes: >

# %% [markdown]
# ### Proportion des valeurs manquantes

# %%
df_missing_proportion = eda.missing_data_proportion(df_properties, in_percente=True)
# Out:
# Les colonnes avec des données manquantes en pourcentage:
#                Column  Missing
# 0        school_taxes    62.42
# 1     municipal_taxes    62.15
# 2              region    57.92
# 3          nb_bedroom    53.54
# 4         nb_bathroom    53.28
# 5   construction_year    26.04
# 6             surface    23.43
# 7                type     9.13
# 8           longitude     0.67
# 9            latitude     0.67
# 10             vendue     0.36
# 11                _id     0.00
# 12           add_date     0.00
# 13               city     0.00
# 14        description     0.00
# 15              price     0.00

# %% [markdown]
# ### Nettoyage des données

# %% [markdown]
# Gérer les valeurs manquantes ou incohérentes :

# %%
# Remplacer les valeurs manquantes pour `type` et `region` par "Inconnu"
df_properties['type'] = df_properties['type'].fillna("Inconnu")
#df_properties['region'] = df_properties['region'].fillna("Inconnu")

# Supprimer les lignes où longitude ou latitude sont nulles (si nécessaire pour une analyse géographique)
df_properties = df_properties.dropna(subset=['longitude', 'latitude'])

# Remplacer les taxes municipales ou scolaires manquantes par 0 (si logique dans ton contexte)
df_properties['municipal_taxes'] = df_properties['municipal_taxes'].fillna(0)
df_properties['school_taxes'] = df_properties['school_taxes'].fillna(0)

# Remplir les colonnes numériques avec des valeurs alternatives (par exemple : médiane)
# df_properties['surface'].fillna(df_properties['surface'].median(), inplace=True)

# %%
# Créer le dictionnaire ville_to_region à partir des colonnes "city" et "region"
ville_to_region = (
    df_properties.dropna(subset=["city", "region"])
    .drop_duplicates(subset=["city"])
    .set_index("city")["region"]
    .to_dict()
)

#print(ville_to_region)

# %%
# Étape 2: Remplir les valeurs manquantes dans la colonne région
df_properties["region"] = df_properties.apply(
    lambda row: ville_to_region.get(row["city"], row["region"]), axis=1
)

# %%
msno.bar(df_properties)
# Out:
# <Axes: >

# %% [markdown]
# ### Save data to csv

# %%
from datetime import datetime


df_properties.to_csv(f'./backup/properties_db_{datetime.now().strftime("%Y%m%d")}.csv', index=False)

# %% [markdown]
# ### Liste des villes avec des propiétées en ventes

# %%
# %%sql
# select distinct city from properties_db where vendue = FALSE
# Out:
# UsageError: Cell magic `%%sql` not found.

# %% [markdown]
# #### Villes avec le plus grand nombre de propriétés

# %%
# %%sql
# select * from (select city from properties
# group by city
# order by count(city) desc limit 15)
# --union select 'Chambly' as city
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 cities = __import__("duckdb").execute(__import__('base64').b64decode('c2VsZWN0ICogZnJvbSAoc2VsZWN0IGNpdHkgZnJvbSBwcm9wZXJ0aWVzCmdyb3VwIGJ5IGNpdHkgCm9yZGVyIGJ5IGNvdW50KGNpdHkpIGRlc2MgbGltaXQgMTUpCi0tdW5pb24gc2VsZWN0ICdDaGFtYmx5JyBhcyBjaXR5Cg==').decode('utf-8')).fetchdf()
#       2 cities
#
# CatalogException: Catalog Error: Table with name properties does not exist!
# Did you mean "pg_settings"?
# LINE 1: select * from (select city from properties
#                                         ^

# %%
# %%sql
# select * from (select city, count(city) from properties
# group by city
# order by count(city) desc limit 15)
# --union select 'Chambly' as city

# %% [markdown]
# #### Villes avec le plus grand nombre de propriétés par mois d'ajout

# %%
# %%sql
# select * from (select city, count(city) nbr_properties, year_month_added from properties
# group by city, year_month_added
# order by count(city) desc)
# --union select 'Chambly' as city

# %%
cities_most_est_by_add_date.to_csv('cities_most_est_by_add_date.csv')

# %%
# %%sql
# select * from cities_most_est_by_add_date where city= 'Trois-Rivières'

# %%
#df= cities_most_est_by_add_date #[df['type'].isin(['Maison','Plex','Condo'])]
df= _df
#df_start = df[df['city'].isin(cities.iloc[4])]
fig = px.bar(df, x="year_month_added", y="nbr_properties",
             labels={'year_month_added': 'Date', 'nbr_properties': 'Nombre de propriétés'},
             width=800, height=700, title=f"Trois-Rivières - Distribution du nombre de propriétés ajoutées par période")

'''cities_buttons = [{'label': x['city'], 'method': 'update',
     'args': 
     [{'x': [df[df['city']==x['city']]['year_month_added']], 
       'y': [df[df['city']==x['city']]['nbr_properties']]
       },{'title': f'{x['city']} - Distribution du nombre de propriétés par type'}]} for i,x in cities.iterrows()]'''

#print(cities_buttons)
#Add dropdown
''' fig.update_layout(
    updatemenus=[
        dict(
            buttons=cities_buttons,
            direction="down",
            pad={"r": 0, "t": 10},
            showactive=True,
            x=-0.1,
            xanchor="left",
            y=1.3,
            yanchor="top"
        ),
    ]
) '''
fig.show()

# %% [markdown]
# ### Nombre de propriétés a vendre par ville et type de propriété

# %%
# %%sql
# select city, type, count(type) as properties_count,min(price),avg(price),max(price), year_month_added
# from properties
# group by city,year_month_added,type
# order by city,year_month_added

# %%
# %%sql
# select sum(properties_count) as count, type,city from (select properties_count,
#                                                       case
#                                                         when type like '%plex%'
#                                                             THEN 'Plex'
#                                                         else type
#                                                         end as type,
#                                                       city
#                                                       from nbr_properties_by_city_typ) group by type,city

# %%
#_df=df #[df['type'].isin(['Maison','Plex','Condo'])]
df_start = df[df['city'].isin(cities.iloc[0])]
fig = px.bar(df_start, x="type", y="count",
             labels={"type":"Type", "count":"Nombre de propriétés"},
             width=800, height=700, title=f"{cities.iloc[0]['city']} - Distribution du nombre de propriétés par type")

cities_buttons = [{'label': x['city'], 'method': 'update',
     'args': 
     [{'x': [df[df['city']==x['city']]['type']], 
       'y': [df[df['city']==x['city']]['count']]
       },{'title': f'{x['city']} - Distribution du nombre de propriétés par type'}]} for i,x in cities.iterrows()]

#print(cities_buttons)
#Add dropdown
fig.update_layout(
    updatemenus=[
        dict(
            buttons=cities_buttons,
            direction="down",
            pad={"r": 0, "t": 10},
            showactive=True,
            x=-0.1,
            xanchor="left",
            y=1.3,
            yanchor="top"
        ),
    ]
)
fig.show()

# %%
# %%sql
# select * from nbr_properties_by_city_typ where city = 'Trois-Rivières' and type = 'Duplex'
#                                 and properties_count > 10
# order by year_month_added asc

# %% [markdown]
# #### Variations du prix moyen par année - mois

# %%
# %%sql
# select * from properties where city = 'Trois-Rivières' and type = 'Duplex'

# %%
fig = px.scatter(df, x="year_month_added", y="price", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()

# %%
fig = px.line(df, x="year_month_added", y="avg(price)",
              #hover_data={"add_date": "|%B %d, %Y"},
              title='custom tick labels')
fig.show()

# %%
# %%sql
# select * from properties_1 where city in (select 'Chambly')

# %%
fig = px.bar(df,x='year_month_added')
fig.show()
