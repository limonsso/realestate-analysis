# %%
from lib.db import convertir_id_en_entier

# %%
convertir_id_en_entier('real_estate_db', 'properties_externe')
# Out:
# ---------------------------------------------------------------------------
# WriteError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 convertir_id_en_entier('real_estate_db', 'properties_externe')
#
# File ~/GitHub/realestate-analysis/lib/db.py:62, in convertir_id_en_entier(db, collection, host, port, username, password)
#      59 id_int = int(id_value)
#      61 # Met à jour le document avec l'id converti en entier
# ---> 62 collection.update_one(
#      63     {'id': document['id']},
#      64     {'$set': {'_id': id_int}}
#      65 )
#      66 #print(f"Document {document['_id']} mis à jour avec l'id {id_int}")
#      67 i += 1  # Augmente i de 1
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/pymongo/collection.py:1086, in Collection.update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, hint, session, let, comment)
# ...
