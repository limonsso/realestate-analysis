# %% [markdown]
# # 📊 Analyse Immobilière - Étapes Individuelles
#
# Ce notebook montre comment exécuter chaque étape de l'analyse immobilière individuellement.
# Cela permet un meilleur contrôle et debugging de chaque étape du processus.

# %% [markdown]
# ## 🔧 Configuration et Imports

# %%
import pandas as pd
import numpy as np
from lib import PropertyAnalyzer, MongoDBLoader
import warnings
warnings.filterwarnings('ignore')

# Initialiser l'analyseur
analyzer = PropertyAnalyzer()

print("🏠 Analyseur immobilier initialisé avec succès!")
# Out:
# 🏠 Analyseur immobilier initialisé avec succès!

# %% [markdown]
# ## 📥 Chargement des Données

# %%
# Option 1: Charger depuis MongoDB
loader = MongoDBLoader()
loader.connect()
df = loader.load_properties()
property_types = loader.load_property_types()
loader.disconnect()

# Option 2: Charger depuis un fichier CSV/Excel
# df = pd.read_csv('votre_fichier.csv')


print(f"📊 Données chargées: {df.shape}")
print(f"📝 Colonnes: {list(df.columns)}")
df.head()
# Out:
# INFO:lib.mongodb_loader:✅ Connexion MongoDB établie: real_estate_db
# INFO:lib.mongodb_loader:✅ 179843 propriétés chargées depuis properties
# INFO:lib.mongodb_loader:✅ 11 types de propriétés chargés
# INFO:lib.mongodb_loader:🔌 Connexion MongoDB fermée
# 📊 Données chargées: (179843, 79)
# 📝 Colonnes: ['_id', '', 'add_date', 'address', 'city', 'company', 'description', 'img_src', 'link', 'plex-revenue', 'price', 'type', 'update_at', 'vendue', 'revenu', 'surface', 'longitude', 'latitude', 'construction_year', 'municipal_taxes', 'school_taxes', 'unites', 'depenses', 'price_assessment', 'nb_bathroom', 'nb_bedroom', 'plex-revenu', 'version', 'region', 'annee', 'geo', 'images', 'nbr_chanbres', 'nbr_sal_bain', 'nbr_sal_deau', 'parking', 'prix_evaluation', 'revenus_annuels_bruts', 'style', 'superficie', 'taxes', 'bathrooms', 'bedrooms', 'building_style', 'commercial_units', 'created_at', 'extraction_metadata', 'full_address', 'image', 'location', 'lot_size', 'main_unit_details', 'municipal_evaluation_building', 'municipal_evaluation_land', 'municipal_evaluation_total', 'municipal_evaluation_year', 'municipal_tax', 'potential_gross_revenue', 'residential_units', 'school_tax', 'updated_at', 'year_built', 'living_area', 'water_rooms', 'basement', 'geolocation', 'evaluation_batiment', 'evaluation_terrain', 'evaluation_total', 'evaluation_year', 'expense', 'expense_period', 'nb_garage', 'nb_parking', 'nb_water_room', 'plex_revenu', 'postal_code', 'revenu_period', 'rooms']
#         _id                     add_date  \
# 0  13363515  2152.0  2022-03-06 00:00:00
# 1  25761492     NaN  2024-07-12 00:00:00
# 2  20417145     NaN  2024-08-22 00:00:00
# 3  23726086     NaN  2024-08-15 00:00:00
# 4  18532646     NaN  2024-07-07 00:00:00
#
#                                              address  \
# 0  {'street': '6926 - 6928, Avenue  Somerled', 'l...
# 1  {'street': '1657, Rue Riendeau', 'locality': '...
# 2  {'street': '1384, Rue de Niverville', 'localit...
# 3  {'street': '952, Rue Chaumont', 'locality': 'C...
# 4  {'street': '1646, Rue Napoléon-Bisson', 'local...
#
#                                              city  company  \
# 0  Montréal (Côte-des-Neiges/Notre-Dame-de-Grâce)  Centris
# 1                                         Chambly  Centris
# 2                                         Chambly  Centris
# 3                                         Chambly  Centris
# 4                                         Chambly  Centris
#
#                                          description  \
# 0  Duplex à vendre à Montréal (Côte-des-Neiges/No...
# 1  Maison à vendre à Chambly, Montérégie, 1657, R...
# 2  Condo à vendre à Chambly, Montérégie, 1384, Ru...
# 3  Maison à vendre à Chambly, Montérégie, 952, Ru...
# 4  Maison à vendre à Chambly, Montérégie, 1646, R...
#
#                                              img_src  \
# 0  https://mspublic.centris.ca/media.ashx?id=ADDD...
# 1  https://mspublic.centris.ca/media.ashx?id=ADDD...
# 2  https://mspublic.centris.ca/media.ashx?id=ADDD...
# 3  https://mspublic.centris.ca/media.ashx?id=ADDD...
# 4  https://mspublic.centris.ca/media.ashx?id=ADDD...
#
#                                                 link  \
# 0  https://www.centris.ca/fr/duplex~a-vendre~mont...
# 1  https://www.centris.ca/fr/maison~a-vendre~cham...
# 2  https://www.centris.ca/fr/condo~a-vendre~chamb...
# 3  https://www.centris.ca/fr/maison~a-vendre~cham...
# 4  https://www.centris.ca/fr/maison~a-vendre~cham...
#
#                  plex-revenue  ...  evaluation_year expense expense_period  \
# 0  Rev. bruts pot. : 26 100 $  ...              NaN     NaN            NaN
# 1                         NaN  ...              NaN     NaN            NaN
# 2                         NaN  ...              NaN     NaN            NaN
# 3                         NaN  ...              NaN     NaN            NaN
# 4                         NaN  ...              NaN     NaN            NaN
#
#   nb_garage  nb_parking  nb_water_room  plex_revenu  postal_code  \
# 0       NaN         NaN            NaN          NaN          NaN
# 1       NaN         NaN            NaN          NaN          NaN
# 2       NaN         NaN            NaN          NaN          NaN
# 3       NaN         NaN            NaN          NaN          NaN
# 4       NaN         NaN            NaN          NaN          NaN
#
#    revenu_period  rooms
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
#
# [5 rows x 79 columns]

# %% [markdown]
# ## 📊 ÉTAPE 1: Validation et Exploration

# %%
# Valider et explorer les données
df_step1 = analyzer.validate_and_explore(df, target_column='price')

# Vous pouvez ajouter votre propre exploration ici
print("\n🔍 Exploration supplémentaire:")
print(f"Types de données:")
print(df_step1.dtypes)

print(f"\nValeurs manquantes par colonne:")
print(df_step1.isnull().sum())
# Out:
# ============================================================
# 📊 ÉTAPE 1: VALIDATION ET EXPLORATION
# ============================================================
# 📊 Données initiales: (179843, 79)
# 🎯 Variable cible: 'price'
#
# 📈 Statistiques de la variable cible 'price':
#    📊 Nombre de valeurs: 179,843
#    💰 Moyenne: 614,752.92
#    📊 Médiane: 499,000.00
#    📉 Min: 0.30
#    📈 Max: 50,000,000.00
#
# 📋 Informations sur les colonnes:
#    📊 Nombre total de colonnes: 79
#    📈 Colonnes numériques: 42
#    📝 Colonnes catégorielles: 37
#    ❓ Valeurs manquantes: 9659334
# ✅ Validation terminée avec succès!
#
# 🔍 Exploration supplémentaire:
# Types de données:
# _id                int64
#                  float64
# add_date          object
# address           object
# city              object
#                   ...
# nb_water_room    float64
# plex_revenu      float64
# postal_code      float64
# revenu_period    float64
# rooms            float64
# Length: 79, dtype: object
#
# Valeurs manquantes par colonne:
# _id                   0
#                  179842
# add_date          57667
# address               0
# city                  0
#                   ...
# nb_water_room    179843
# plex_revenu      179843
# postal_code      179843
# revenu_period    179843
# rooms            179842
# Length: 79, dtype: int64

# %% [markdown]
# ## 🧹 ÉTAPE 2: Nettoyage des Données

# %%
# Nettoyer les données
df_step2 = analyzer.clean_data(df_step1)

print("\n🔍 Vérification après nettoyage:")
print(f"Colonnes restantes: {list(df_step2.columns)}")
print(f"Forme des données: {df_step2.shape}")

df_step2.head()
# Out:
# INFO:lib.data_processors:🧹 Nettoyage des données MongoDB...
# ============================================================
# 🧹 ÉTAPE 2: NETTOYAGE DES DONNÉES
# ============================================================
#
# 📊 === ÉTAPE 1: ANALYSE INITIALE ===
# 📋 Nombre total de colonnes au début: 79
# 📝 Colonnes initiales: ['_id', '', 'add_date', 'address', 'city', 'company', 'description', 'img_src', 'link', 'plex-revenue', 'price', 'type', 'update_at', 'vendue', 'revenu', 'surface', 'longitude', 'latitude', 'construction_year', 'municipal_taxes', 'school_taxes', 'unites', 'depenses', 'price_assessment', 'nb_bathroom', 'nb_bedroom', 'plex-revenu', 'version', 'region', 'annee', 'geo', 'images', 'nbr_chanbres', 'nbr_sal_bain', 'nbr_sal_deau', 'parking', 'prix_evaluation', 'revenus_annuels_bruts', 'style', 'superficie', 'taxes', 'bathrooms', 'bedrooms', 'building_style', 'commercial_units', 'created_at', 'extraction_metadata', 'full_address', 'image', 'location', 'lot_size', 'main_unit_details', 'municipal_evaluation_building', 'municipal_evaluation_land', 'municipal_evaluation_total', 'municipal_evaluation_year', 'municipal_tax', 'potential_gross_revenue', 'residential_units', 'school_tax', 'updated_at', 'year_built', 'living_area', 'water_rooms', 'basement', 'geolocation', 'evaluation_batiment', 'evaluation_terrain', 'evaluation_total', 'evaluation_year', 'expense', 'expense_period', 'nb_garage', 'nb_parking', 'nb_water_room', 'plex_revenu', 'postal_code', 'revenu_period', 'rooms']
#
# 📈 Statistiques des valeurs manquantes:
#    📉 : 179,842 (100.0%)
#    📉 add_date: 57,667 (32.1%)
#    📉 company: 57,666 (32.1%)
#    📉 description: 57,669 (32.1%)
#    📉 img_src: 73,894 (41.1%)
#    📉 plex-revenue: 163,692 (91.0%)
#    📉 type: 10,071 (5.6%)
#    📉 vendue: 403 (0.2%)
#    📉 revenu: 160,509 (89.2%)
#    📉 surface: 88,235 (49.1%)
#    📉 longitude: 752 (0.4%)
#    📉 latitude: 752 (0.4%)
#    📉 construction_year: 88,213 (49.0%)
#    📉 municipal_taxes: 138,452 (77.0%)
#    📉 school_taxes: 138,714 (77.1%)
#    📉 unites: 102,815 (57.2%)
#    📉 depenses: 176,300 (98.0%)
#    📉 price_assessment: 161,352 (89.7%)
#    📉 nb_bathroom: 118,007 (65.6%)
#    📉 nb_bedroom: 118,357 (65.8%)
#    📉 plex-revenu: 172,922 (96.2%)
#    📉 version: 110,256 (61.3%)
#    📉 region: 63,173 (35.1%)
#    📉 annee: 179,842 (100.0%)
#    📉 geo: 179,842 (100.0%)
#    📉 images: 96,801 (53.8%)
#    📉 nbr_chanbres: 179,842 (100.0%)
#    📉 nbr_sal_bain: 179,842 (100.0%)
#    📉 nbr_sal_deau: 179,843 (100.0%)
#    📉 parking: 124,755 (69.4%)
#    📉 prix_evaluation: 179,842 (100.0%)
#    📉 revenus_annuels_bruts: 179,843 (100.0%)
#    📉 style: 179,842 (100.0%)
#    📉 superficie: 179,842 (100.0%)
#    📉 taxes: 179,842 (100.0%)
#    📉 bathrooms: 107,497 (59.8%)
#    📉 bedrooms: 107,902 (60.0%)
#    📉 building_style: 134,618 (74.8%)
#    📉 commercial_units: 96,802 (53.8%)
#    📉 created_at: 96,802 (53.8%)
#    📉 extraction_metadata: 96,802 (53.8%)
#    📉 full_address: 96,802 (53.8%)
#    📉 image: 96,803 (53.8%)
#    📉 location: 96,821 (53.8%)
#    📉 lot_size: 131,742 (73.2%)
#    📉 main_unit_details: 173,043 (96.2%)
#    📉 municipal_evaluation_building: 121,668 (67.7%)
#    📉 municipal_evaluation_land: 119,468 (66.4%)
#    📉 municipal_evaluation_total: 104,160 (57.9%)
#    📉 municipal_evaluation_year: 106,609 (59.3%)
#    📉 municipal_tax: 116,526 (64.8%)
#    📉 potential_gross_revenue: 173,037 (96.2%)
#    📉 residential_units: 96,802 (53.8%)
#    📉 school_tax: 117,288 (65.2%)
#    📉 updated_at: 96,802 (53.8%)
#    📉 year_built: 120,197 (66.8%)
#    📉 living_area: 168,025 (93.4%)
#    📉 water_rooms: 155,706 (86.6%)
#    📉 basement: 149,922 (83.4%)
#    📉 geolocation: 179,841 (100.0%)
#    📉 evaluation_batiment: 179,843 (100.0%)
#    📉 evaluation_terrain: 179,843 (100.0%)
#    📉 evaluation_total: 179,843 (100.0%)
#    📉 evaluation_year: 179,843 (100.0%)
#    📉 expense: 179,843 (100.0%)
#    📉 expense_period: 179,843 (100.0%)
#    📉 nb_garage: 179,843 (100.0%)
#    📉 nb_parking: 179,843 (100.0%)
#    📉 nb_water_room: 179,843 (100.0%)
#    📉 plex_revenu: 179,843 (100.0%)
#    📉 postal_code: 179,843 (100.0%)
#    📉 revenu_period: 179,843 (100.0%)
#    📉 rooms: 179,842 (100.0%)
#
# 🗑️ === ÉTAPE 2: SUPPRESSION DES COLONNES MONGODB ===
# ❌ Colonnes MongoDB à supprimer (18):
#    🗑️ _id
#    🗑️ link
#    🗑️ images
#    🗑️ img_src
#    🗑️ image
#    🗑️ add_date
#    🗑️ update_at
#    🗑️ created_at
#    🗑️ updated_at
#    🗑️ extraction_metadata
#    🗑️ location
#    🗑️ parking
#    🗑️ unites
#    🗑️ commercial_units
#    🗑️ residential_units
#    🗑️ description
#    🗑️ full_address
#    🗑️ address
# ❌ Colonnes de métadonnées à supprimer (4):
#    🗑️ company
#    🗑️ vendue
#    🗑️ version
#    🗑️ add_date
#
# 📊 Résultat étape 2:
#    📉 Colonnes supprimées: 22
#    📈 Colonnes restantes: 58
#
# 🗑️ === ÉTAPE 3: SUPPRESSION DES COLONNES AVEC TROP DE VALEURS MANQUANTES ===
# 🎯 Seuil de conservation: 5.0% (garder colonnes avec ≥5.0% de données valides)
#
# ❌ Colonnes à supprimer (29):
#    🗑️ : 100.0% manquantes
#    🗑️ depenses: 98.0% manquantes
#    🗑️ plex-revenu: 96.2% manquantes
#    🗑️ annee: 100.0% manquantes
#    🗑️ geo: 100.0% manquantes
#    🗑️ nbr_chanbres: 100.0% manquantes
#    🗑️ nbr_sal_bain: 100.0% manquantes
#    🗑️ nbr_sal_deau: 100.0% manquantes
#    🗑️ prix_evaluation: 100.0% manquantes
#    🗑️ revenus_annuels_bruts: 100.0% manquantes
#    🗑️ style: 100.0% manquantes
#    🗑️ superficie: 100.0% manquantes
#    🗑️ taxes: 100.0% manquantes
#    🗑️ main_unit_details: 96.2% manquantes
#    🗑️ potential_gross_revenue: 96.2% manquantes
#    🗑️ geolocation: 100.0% manquantes
#    🗑️ evaluation_batiment: 100.0% manquantes
#    🗑️ evaluation_terrain: 100.0% manquantes
#    🗑️ evaluation_total: 100.0% manquantes
#    🗑️ evaluation_year: 100.0% manquantes
#    🗑️ expense: 100.0% manquantes
#    🗑️ expense_period: 100.0% manquantes
#    🗑️ nb_garage: 100.0% manquantes
#    🗑️ nb_parking: 100.0% manquantes
#    🗑️ nb_water_room: 100.0% manquantes
#    🗑️ plex_revenu: 100.0% manquantes
#    🗑️ postal_code: 100.0% manquantes
#    🗑️ revenu_period: 100.0% manquantes
#    🗑️ rooms: 100.0% manquantes
#
# ✅ Colonnes conservées (29):
#    💚 city: 100.0% valides
#    💚 plex-revenue: 9.0% valides
#    💚 price: 100.0% valides
#    💚 type: 94.4% valides
#    💚 revenu: 10.8% valides
#    💚 surface: 50.9% valides
#    💚 longitude: 99.6% valides
#    💚 latitude: 99.6% valides
#    💚 construction_year: 50.9% valides
#    💚 municipal_taxes: 23.0% valides
#    💚 school_taxes: 22.9% valides
#    💚 price_assessment: 10.3% valides
#    💚 nb_bathroom: 34.4% valides
#    💚 nb_bedroom: 34.2% valides
#    💚 region: 64.9% valides
#    💚 bathrooms: 40.2% valides
#    💚 bedrooms: 40.0% valides
#    💚 building_style: 25.1% valides
#    💚 lot_size: 26.7% valides
#    💚 municipal_evaluation_building: 32.3% valides
#    💚 municipal_evaluation_land: 33.6% valides
#    💚 municipal_evaluation_total: 42.1% valides
#    💚 municipal_evaluation_year: 40.7% valides
#    💚 municipal_tax: 35.2% valides
#    💚 school_tax: 34.8% valides
#    💚 year_built: 33.2% valides
#    💚 living_area: 6.6% valides
#    💚 water_rooms: 13.4% valides
#    💚 basement: 16.6% valides
#
# 📊 Résultat étape 3:
#    📉 Colonnes supprimées: 29
#    📈 Colonnes restantes: 29
#
# 🧹 === ÉTAPE 4: SUPPRESSION DES COLONNES INUTILES ===
# ✅ Aucune colonne inutile trouvée
#
# 📊 Résultat étape 4:
#    📉 Colonnes supprimées: 0
#    📈 Colonnes restantes: 29
#
# ✅ Colonnes finales conservées (29):
#     1. city
#     2. plex-revenue
#     3. price
#     4. type
#     5. revenu
#     6. surface
#     7. longitude
#     8. latitude
#     9. construction_year
#    10. municipal_taxes
#    11. school_taxes
#    12. price_assessment
#    13. nb_bathroom
#    14. nb_bedroom
#    15. region
#    16. bathrooms
#    17. bedrooms
#    18. building_style
#    19. lot_size
#    20. municipal_evaluation_building
#    21. municipal_evaluation_land
#    22. municipal_evaluation_total
#    23. municipal_evaluation_year
#    24. municipal_tax
#    25. school_tax
#    26. year_built
#    27. living_area
#    28. water_rooms
#    29. basement
#
# 🔄 === ÉTAPE 5: NORMALISATION DES COLONNES ===
#    🔄 Normalisation: nb_bathroom → bathrooms
#    🔄 Normalisation: nb_bedroom → bedrooms
#    🔄 Normalisation: construction_year → year_built
#    🔄 Normalisation: municipal_taxes → municipal_tax
#    🔄 Normalisation: school_taxes → school_tax
#    🔄 Conversion: bathrooms → numérique
#    🔄 Conversion: bedrooms → numérique
#    🔄 Conversion: year_built → numérique
#    🔄 Conversion: municipal_tax → numérique
#    🔄 Conversion: school_tax → numérique
#
# ⚠️ Pas de normalisation des types (normalisateur non disponible ou colonne 'type' manquante)
#
# 🏆 === RÉSUMÉ FINAL DU NETTOYAGE ===
# 📊 Colonnes initiales: 79
# 📊 Colonnes finales: 24
# 📉 Total supprimées: 55
# 📈 Pourcentage conservé: 30.4%
# 📈 Valeurs manquantes avant: 9,659,334
# 📉 Valeurs manquantes après: 2,409,864
# 📊 Réduction valeurs manquantes: 75.1%
# 📊 Résultats du nettoyage:
#    📈 Lignes: 179,843 → 179,843
#    📊 Colonnes: 79 → 24
#    📉 Colonnes supprimées: 55
# ✅ Nettoyage terminé avec succès!
#
# 🔍 Vérification après nettoyage:
# Colonnes restantes: ['city', 'plex-revenue', 'price', 'type', 'revenu', 'surface', 'longitude', 'latitude', 'price_assessment', 'region', 'bathrooms', 'bedrooms', 'building_style', 'lot_size', 'municipal_evaluation_building', 'municipal_evaluation_land', 'municipal_evaluation_total', 'municipal_evaluation_year', 'municipal_tax', 'school_tax', 'year_built', 'living_area', 'water_rooms', 'basement']
# Forme des données: (179843, 24)
#                                              city                plex-revenue  \
# 0  Montréal (Côte-des-Neiges/Notre-Dame-de-Grâce)  Rev. bruts pot. : 26 100 $
# 1                                         Chambly                         NaN
# 2                                         Chambly                         NaN
# 3                                         Chambly                         NaN
# 4                                         Chambly                         NaN
#
#       price    type  revenu  surface  longitude   latitude  price_assessment  \
# 0  749000.0  Duplex     NaN      NaN        NaN        NaN               NaN
# 1  574900.0  Maison     NaN      NaN -73.292301  45.430607               NaN
# 2  448800.0   Condo     NaN   1266.0 -73.297033  45.432642          361000.0
# 3  519900.0  Maison     NaN      NaN -73.287130  45.442001               NaN
# 4  848500.0  Maison     NaN   3922.0 -73.322884  45.434597               NaN
#
#   region  ...  municipal_evaluation_building  municipal_evaluation_land  \
# 0    NaN  ...                            NaN                        NaN
# 1    NaN  ...                            NaN                        NaN
# 2    NaN  ...                            NaN                        NaN
# 3    NaN  ...                            NaN                        NaN
# 4    NaN  ...                            NaN                        NaN
#
#   municipal_evaluation_total  municipal_evaluation_year  municipal_tax  \
# 0                        NaN                        NaN            NaN
# 1                        NaN                        NaN            NaN
# 2                        NaN                        NaN            NaN
# 3                        NaN                        NaN            NaN
# 4                        NaN                        NaN            NaN
#
#    school_tax  year_built  living_area  water_rooms  basement
# 0         NaN         NaN          NaN          NaN       NaN
# 1         NaN         NaN          NaN          NaN       NaN
# 2         NaN         NaN          NaN          NaN       NaN
# 3         NaN         NaN          NaN          NaN       NaN
# 4         NaN         NaN          NaN          NaN       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 🔄 ÉTAPE 3: Normalisation des Variables

# %%
# Normaliser les variables catégorielles
df_step3 = analyzer.normalize_variables(df_step2)

print("\n🔍 Vérification après normalisation:")
print(f"Colonnes: {list(df_step3.columns)}")

# Vérifier les changements dans les variables catégorielles
categorical_cols = df_step3.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\n📊 Variable '{col}':")
    print(f"   Valeurs uniques: {df_step3[col].nunique()}")
    print(f"   Valeurs: {list(df_step3[col].unique())}")

df_step3.head()
# Out:
# ============================================================
# 🔄 ÉTAPE 3: NORMALISATION DES VARIABLES
# ============================================================
# INFO:lib.property_type_normalizer:🏠 Normalisation des types de propriétés...
# 🏠 Normalisation des types de propriétés avec PropertyTypeNormalizer:
#
# 📊 Types avant normalisation:
#    📝 Maison: 35059 propriétés
#    📝 Maison à vendre: 34308 propriétés
#    📝 Condo à vendre: 17965 propriétés
#    📝 House for sale: 16125 propriétés
#    📝 Condo: 14297 propriétés
#    📝 Lot for sale: 8957 propriétés
#    📝 Duplex: 7389 propriétés
#    📝 Terrain à vendre: 5608 propriétés
#    📝 Condo for sale: 4836 propriétés
#    📝 Triplex: 4416 propriétés
#
# ✅ Types après normalisation:
#    🏷️ unknown: 179843 propriétés
#
# ⚠️ Types non reconnus (43):
#    ❓ Chalet
#    ❓ Chalet à vendre
#    ❓ Chalet à vendre ou à louer
#    ❓ Condo
#    ❓ Condo for sale
#    ❓ Condo à vendre
#    ❓ Condo à vendre ou à louer
#    ❓ Condominium house for sale
#    ❓ Cottage for sale
#    ❓ Duplex
#
# 🏙️ Normalisation de 'city':
#       Villes: 1208 → 1208
#
# 🗺️ Normalisation de 'region':
#       Régions: 3109 → 3106
#
# 🏗️ Normalisation de 'building_style':
#       Styles: 18 → 18
#
# 📊 Résultats de la normalisation:
#    📈 Lignes: 179,843 → 179,843
#    📊 Colonnes: 24 → 25
#    🔄 type: 43 → 1 valeurs uniques
#    🔄 region: 3109 → 3106 valeurs uniques
# ✅ Normalisation terminée avec succès!
#
# 🔍 Vérification après normalisation:
# Colonnes: ['city', 'plex-revenue', 'price', 'type', 'revenu', 'surface', 'longitude', 'latitude', 'price_assessment', 'region', 'bathrooms', 'bedrooms', 'building_style', 'lot_size', 'municipal_evaluation_building', 'municipal_evaluation_land', 'municipal_evaluation_total', 'municipal_evaluation_year', 'municipal_tax', 'school_tax', 'year_built', 'living_area', 'water_rooms', 'basement', 'type_id']
#
# 📊 Variable 'city':
#    Valeurs uniques: 1208
#    Valeurs: ['Montréal (Côte-Des-Neiges/Notre-Dame-De-Grâce)', 'Chambly', 'Saint-Donat', 'Carignan', 'Saint-Basile-Le-Grand', 'Longueuil', 'Québec', 'Saint-Hyacinthe', 'Lévis', 'Montréal', 'Sherbrooke', 'Granby', 'Mirabel', 'Yamachiche', 'Louiseville', "Saint-Adolphe-D'Howard", 'Saint-Jean-Sur-Richelieu', 'Vaudreuil-Dorion', 'Salaberry-De-Valleyfield', 'Saint-Zotique', 'Brossard', 'Varennes', 'Otterburn Park', 'Châteauguay', 'Beloeil', 'Sainte-Julie', 'Longueuil (Saint-Hubert)', 'Saint-Lambert', 'Mont-Saint-Hilaire', 'Hudson', 'Saint-Bruno-De-Montarville', 'Les Cèdres', 'Hemmingford - Canton', "L'Île-Perrot", 'Coteau-Du-Lac', 'Boucherville', 'Saint-Antoine-Sur-Richelieu', 'Mercier', 'Pincourt', 'Hinchinbrooke', 'Sainte-Catherine', 'La Prairie', "Saint-Paul-D'Abbotsford", 'Vaudreuil-Sur-Le-Lac', 'Saint-Anicet', "Notre-Dame-De-L'Île-Perrot", 'Saint-Denis-Sur-Richelieu', 'Beauharnois', 'Saint-Ours', 'Saint-Michel', 'Pointe-Des-Cascades', 'Candiac', 'Sainte-Clotilde', 'Venise-En-Québec', 'Sainte-Marie-Madeleine', 'Saint-Mathias-Sur-Richelieu', 'Saint-Stanislas-De-Kostka', 'Marieville', 'Saint-Roch-De-Richelieu', 'Saint-Louis', 'Saint-Mathieu-De-Beloeil', 'Sainte-Martine', 'Sorel-Tracy', 'Saint-Valentin', 'Contrecoeur', 'Pointe-Fortune', 'Sainte-Marthe', 'Saint-Rémi', 'Clarenceville', "Saint-Paul-De-L'Île-Aux-Noix", 'Saint-Amable', 'Longueuil (Greenfield Park)', 'Napierville', 'Saint-Césaire', 'Les Coteaux', 'Richelieu', 'Saint-Philippe', 'Saint-Chrysostome', 'Rougemont', 'Saint-Urbain-Premier', 'Sainte-Anne-De-Sabrevois', 'Saint-Lazare', 'Saint-Marc-Sur-Richelieu', 'Elgin', 'Mont-Saint-Grégoire', 'Saint-Constant', 'Saint-Bernard-De-Lacolle', 'Sainte-Anne-De-Sorel', 'Rigaud', "Saint-Théodore-D'Acton", 'Sainte-Victoire-De-Sorel', 'Sainte-Barbe', 'Saint-Étienne-De-Beauharnois', 'Rivière-Beaudette', 'Calixa-Lavallée', 'Saint-Pie', 'Lacolle', 'Henryville', 'Léry', 'Acton Vale', 'Noyan', 'Très-Saint-Rédempteur', 'Saint-Blaise-Sur-Richelieu', 'Ange-Gardien', 'Mcmasterville', 'Sainte-Hélène-De-Bagot', 'Sainte-Madeleine', 'Longueuil (Le Vieux-Longueuil)', 'Ormstown', 'Massueville', 'Saint-Mathieu', 'Saint-Valérien-De-Milton', 'Huntingdon', 'Saint-Cyprien-De-Napierville', 'Saint-Jacques-Le-Mineur', 'Saint-Louis-De-Gonzague', 'Saint-Bernard-De-Michaudville', 'Saint-Polycarpe', 'Saint-Liboire', 'Howick', 'Dundee', "L'Île-Cadieux", 'Saint-Barnabé-Sud', 'Saint-Dominique', 'Delson', 'Saint-Lambert (Montérégie)', 'Saint-Isidore', 'Verchères', 'Shawinigan', 'Québec (Beauport)', 'Saint-Alexis-Des-Monts', 'Saint-Mathieu-Du-Parc', 'Lac-Édouard', 'Lac-Normand', 'Trois-Rivières', 'Québec (La Haute-Saint-Charles)', 'Val-Des-Sources', 'Cowansville', 'Sainte-Geneviève-De-Batiscan', 'Hatley - Canton', 'Shefford', 'Magog', 'Potton', 'Lambton', 'Austin', 'Bromont', 'Saint-Alphonse-De-Granby', 'Sherbrooke (Brompton/Rock Forest/Saint-Élie/Deauville)', 'Saint-Claude', 'Coaticook', 'Waterloo', 'Lac-Brome', 'Compton', 'Stukely-Sud', 'Danville', 'Farnham', 'Richmond', 'Orford', 'Wotton', 'Sainte-Sabine', 'Sutton', 'Eastman', 'Saint-Boniface', 'Sainte-Catherine-De-Hatley', 'Saint-Léon-Le-Grand', "Ayer'S Cliff", 'Bonsecours', 'Valcourt - Canton', 'Stoke', 'Saint-Édouard-De-Maskinongé', 'Saint-Sébastien', 'Lac-Aux-Sables', 'Dixville', 'Notre-Dame-Des-Bois', 'Newport', 'Champlain', 'Saint-Denis-De-Brompton', 'Bolton-Est', 'Saint-Armand', 'Notre-Dame-Du-Mont-Carmel', 'Sainte-Cécile-De-Milton', 'Windsor', 'Dunham', 'Bedford - Canton', 'Racine', 'Stanstead - Canton', 'Bedford - Ville', 'Val-Joli', 'La Tuque', 'Scotstown', 'Sainte-Thècle', 'Weedon', 'Saint-Élie-De-Caxton', 'Sainte-Anne-De-La-Rochelle', 'Chartierville', 'Marston', 'Bury', 'Maskinongé', 'Saint-Joachim-De-Shefford', 'Ascot Corner', 'Charette', 'Roxton Pond', 'Saint-Barnabé', 'Québec (Charlesbourg)', 'Saint-Tite', 'Stanstead - Ville', 'Maricourt', 'Saint-Étienne-De-Bolton', 'Stratford', 'Brigham', 'Lingwick', 'Saint-Georges-De-Windsor', 'La Bostonnais', 'Pike River', 'Saint-Adelphe', 'Hatley - Municipalité',  ...
#
# 📊 Variable 'plex-revenue':
#    Valeurs uniques: 3957
#    Valeurs: ['Rev. bruts pot. : 26 100 $', nan, 'Rev. bruts pot. : 36 000 $', 'Rev. bruts pot. : 39 468 $', 'Rev. bruts pot. : 21 960 $', 'Pot. Gross Rev.: $39,720', 'Rev. bruts pot. : 21 204 $', 'Rev. bruts pot. : 49 800 $', 'Rev. bruts pot. : 51 000 $', 'Rev. bruts pot. : 1 428 $', 'Pot. Gross Rev.: $11,880', 'Rev. bruts pot. : 117 000 $', 'Rev. bruts pot. : 41 820 $', 'Rev. bruts pot. : 41 016 $', 'Rev. bruts pot. : 43 440 $', 'Rev. bruts pot. : 22 740 $', 'Rev. bruts pot. : 36 120 $', 'Rev. bruts pot. : 53 940 $', 'Rev. bruts pot. : 37 620 $', 'Rev. bruts pot. : 62 496 $', 'Rev. bruts pot. : 20 520 $', 'Rev. bruts pot. : 55 740 $', 'Rev. bruts pot. : 42 300 $', 'Rev. bruts pot. : 29 076 $', 'Pot. Gross Rev.: $40,560', 'Rev. bruts pot. : 36 600 $', 'Rev. bruts pot. : 22 260 $', 'Rev. bruts pot. : 27 372 $', 'Rev. bruts pot. : 30 660 $', 'Rev. bruts pot. : 37 200 $', 'Rev. bruts pot. : 40 200 $', 'Rev. bruts pot. : 44 640 $', 'Rev. bruts pot. : 24 960 $', 'Rev. bruts pot. : 29 700 $', 'Rev. bruts pot. : 31 800 $', 'Rev. bruts pot. : 33 720 $', 'Rev. bruts pot. : 17 400 $', 'Rev. bruts pot. : 37 440 $', 'Rev. bruts pot. : 36 396 $', 'Rev. bruts pot. : 56 100 $', 'Pot. Gross Rev.: $32,400', 'Pot. Gross Rev.: $62,400', 'Rev. bruts pot. : 49 200 $', 'Pot. Gross Rev.: $49,920', 'Rev. bruts pot. : 23 040 $', 'Rev. bruts pot. : 35 160 $', 'Rev. bruts pot. : 55 200 $', 'Rev. bruts pot. : 48 000 $', 'Rev. bruts pot. : 57 300 $', 'Pot. Gross Rev.: $44,400', 'Rev. bruts pot. : 37 020 $', 'Rev. bruts pot. : 51 900 $', 'Rev. bruts pot. : 44 400 $', 'Rev. bruts pot. : 28 920 $', 'Pot. Gross Rev.: $38,400', 'Rev. bruts pot. : 38 100 $', 'Rev. bruts pot. : 31 020 $', 'Rev. bruts pot. : 34 320 $', 'Rev. bruts pot. : 60 000 $', 'Rev. bruts pot. : 35 880 $', 'Rev. bruts pot. : 45 780 $', 'Rev. bruts pot. : 36 060 $', 'Rev. bruts pot. : 44 760 $', 'Rev. bruts pot. : 41 964 $', 'Rev. bruts pot. : 46 200 $', 'Rev. bruts pot. : 44 580 $', 'Pot. Gross Rev.: $56,400', 'Rev. bruts pot. : 58 200 $', 'Rev. bruts pot. : 31 080 $', 'Rev. bruts pot. : 38 400 $', 'Rev. bruts pot. : 33 780 $', 'Rev. bruts pot. : 36 540 $', 'Rev. bruts pot. : 26 820 $', 'Rev. bruts pot. : 30 480 $', 'Rev. bruts pot. : 30 060 $', 'Rev. bruts pot. : 46 380 $', 'Rev. bruts pot. : 19 020 $', 'Rev. bruts pot. : 38 520 $', 'Rev. bruts pot. : 25 260 $', 'Rev. bruts pot. : 48 240 $', 'Pot. Gross Rev.: $25,680', 'Pot. Gross Rev.: $56,940', 'Pot. Gross Rev.: $72,000', 'Pot. Gross Rev.: $49,500', 'Rev. bruts pot. : 12 180 $', 'Pot. Gross Rev.: $19,920', 'Rev. bruts pot. : 39 540 $', 'Pot. Gross Rev.: $46,560', 'Rev. bruts pot. : 31 764 $', 'Pot. Gross Rev.: $55,800', 'Rev. bruts pot. : 25 560 $', 'Rev. bruts pot. : 24 000 $', 'Pot. Gross Rev.: $41,100', 'Pot. Gross Rev.: $52,847', 'Pot. Gross Rev.: $37,812', 'Rev. bruts pot. : 32 400 $', 'Rev. bruts pot. : 23 400 $', 'Rev. bruts pot. : 28 800 $', 'Pot. Gross Rev.: $46,200', 'Rev. bruts pot. : 28 080 $', 'Rev. bruts pot. : 41 460 $', 'Pot. Gross Rev.: $33,180', 'Pot. Gross Rev.: $49,104', 'Rev. bruts pot. : 23 820 $', 'Rev. bruts pot. : 40 800 $', 'Rev. bruts pot. : 17 640 $', 'Rev. bruts pot. : 14 100 $', 'Rev. bruts pot. : 66 900 $', 'Rev. bruts pot. : 38 940 $', 'Rev. bruts pot. : 41 100 $', 'Rev. bruts pot. : 21 000 $', 'Rev. bruts pot. : 27 000 $', 'Rev. bruts pot. : 45 000 $', 'Rev. bruts pot. : 34 200 $', 'Pot. Gross Rev.: $27,180', 'Rev. bruts pot. : 13 320 $', 'Rev. bruts pot. : 51 528 $', 'Pot. Gross Rev.: $33,708', 'Rev. bruts pot. : 40 320 $', 'Rev. bruts pot. : 38 220 $', 'Rev. bruts pot. : 34 800 $', 'Rev. bruts pot. : 22 860 $', 'Rev. bruts pot. : 17 520 $', 'Pot. Gross Rev.: $10,800', 'Rev. bruts pot. : 31 500 $', 'Rev. bruts pot. : 42 000 $', 'Rev. bruts pot. : 52 260 $', 'Rev. bruts pot. : 35 040 $', 'Rev. bruts pot. : 26 520 $', 'Pot. Gross Rev.: $25,800', 'Rev. bruts pot. : 39 000 $', 'Rev. bruts pot. : 92 400 $', 'Rev. bruts pot. : 31 896 $', 'Rev. bruts pot. : 56 928 $', 'Rev. bruts pot. : 32 220 $', 'Rev. bruts po ...
#
# 📊 Variable 'type':
#    Valeurs uniques: 1
#    Valeurs: ['unknown']
#
# 📊 Variable 'region':
#    Valeurs uniques: 3106
#    Valeurs: [nan, 'Montérégie', 'Montréal (Île)', 'Estrie', 'Laurentides', 'Lanaudière', 'Chaudière-Appalaches', 'Laval', 'Mauricie', 'Rue De La Faune', '390', '82', '10', 'Capitale-Nationale', 'Rue Lafontaine', '4', 'Boulevard De Comporté', 'Route Campagna', 'Avenue Du Phare Est', '1917', 'Québec', 'Outaouais', '11E Avenue', '552', '322', '5', '10E Rue', '95', 'Route 170', '1Re Avenue Est', 'Rue Pinder Est', '60', 'Abitibi-Témiscamingue', 'Rue Lapointe', 'Bas-Saint-Laurent', 'Avenue Royale', "Rue De L'Académie", 'Montréal (Island)', 'Route 204', 'Rue Du Manoir Ouest', "Rue De L'Église", '12090', '51Z', 'Rue Groleau', '127', '661', 'Avenue Cartier', '305', '42', 'Avenue Painchaud', '141', 'Chemin Des Belvédères', '17', 'Avenue Arnaud', '11485', '37', '149', 'Rue Guyon', '101', 'Rue De Nantes', '4E Rang', '1130', '1577Z', '1295', '1297', '1301', '375', '440', '777', '63', 'Apt. 1507', '5454', 'Apt. 1301', '54', 'Boulevard Charest Est', '1400', '760', '999', '76', '1577', '39', '69', '1430', '102', '30', '160', 'Apt. 901', 'Apt. 1909', 'Apt. 1601', '46', '51', '368', '11', 'Chemin Des Pionniers Ouest', '325', '500Z', '9152', 'Rue Des Roseaux', 'Route 113 Sud', 'Rue Pouliot', 'Chemin Des Bouleaux', '308', 'Rue Des Anémones', '1791', '7201', '9', 'Boulevard Perron Ouest', '169', '302', 'Route Lauzier', '97', 'Route 199', '11E Rang', '1277', '5155', '307', 'Rue Des Loups', 'Gaspésie', 'Rue De Coutances', '170', 'Route 132 Ouest', '155', 'Chemin Chagnon', '670', '45', 'Rue De La Grève', '1Re Avenue', 'Rue Roy', '78', '3492', '5768623', '465', '43', 'Rue De La Tourbière', '13', 'Rue De Dover', 'Route 299', '312', "Avenue De L'Or", 'Rue Du Pinot', '881', 'Rang Pariseau', 'Rue Des Tulipes', '1935', 'Route 138', '5047', 'Rue Des Cèdres', '53', '01', 'Rue Principale', 'Rue Paquet', 'Route 132', '128', 'Route 265', 'Chemin Groleau', 'Chemin Des Berges', '33', 'Avenue De La Madawaska', '4E Avenue Ouest', '1066', '467', '56', '301', 'Chemin De La Vernière', '48', '94', '5E Avenue Ouest', 'Rue Du Boisé', '550', '35', 'Rue Préfontaine', '12', 'Rue De Bonaventure', '806', '71', 'Rue Des Merisiers', '59', 'X', '40', 'Chemin Beauchastel', 'Rue Chapados', '389', '711Z', '19', '11725', '184', 'Gaspesie--Iles-De-La-Madeleine', '113', '912', '5201', 'Route 161', 'Chemin Bourgeois', 'Rue De La Taïga', '62', '772', 'Rue Des Bolets', 'Rue Des Prés', 'Apt. 306', '131', '1161', '833', '111', '1435', 'Avenue Du Pont Nord', '107', '1Re Rue Est', '356', 'Rue Gauthier', '355', '15', '629', 'Chemin Du Camping', '44', 'Chemin Des Érables', 'Chemin Du Golf', '61', 'Apt. 2301', '1', '1550', '68E Avenue', 'Rue Principale Ouest', '1332', 'Rue Commerciale', '613', '948Z', 'B', '345', 'Rue Des Bourgeois', '1549', '492', '306', '100', '5660', '1407', '139Z', 'Rue Du Nordet', "Chemin De L'Oasis", '750', '1331', '316', '136', '74', '775', '5209135', '1546', '16', 'Chemin Du Lac Sud', 'Rue Des Montagnes', '1042', '1091', '109', 'Boulevard Rideau', '175', '1960', '85', '551', '80', '151', '8', '7263', '9749', 'Rue Des Eiders', 'Rue Authier', 'Rue De La Rivière', '783', '332', '3', '1201', '137', 'Chemin De La Martine', '6', 'Boulevard Talbot', 'Route 232 Est', '348', '407', '911', 'Rue De Normandie', 'Avenue Des Verbourgs', 'Chemin Du Lac', 'Rue Boucher', 'Chemin De La Bourgade', '956', 'Rue Labrie', 'Rue De La Vallée', '1556', 'Chemin Savard', 'Chemin De La Mer Est', 'Rue De La Gare', '65', 'Route Tardif', 'Route 295', '185', '571', 'Chemin De La Bleuetière', '318', "Rue De L'Horizon", '643', 'Route Du Phare', '749', '405', '109E Rue', '75', '730', '77', 'Boulevard Laurier', '186', 'Boulevard Bégin', '438', '1M', 'Rue Des Fougères', '52', 'Rue Laurette', '377', 'Rue Thibault', '955', '106', '3422', '369', 'Rue Du Repos', '380', 'Apt. 2101', '469', '129', 'Route Du Lac', 'Chemin Du Versant', '4957', 'Rue Des Coteaux', 'Boulevard Forest', 'E', '341', 'Chemin De La Pointe', '8E Rang', '4955', '32', '14', 'A', 'Rue Druillettes', 'Rue Des Châtaignes', '1064', 'Chemin De La M ...
#
# 📊 Variable 'building_style':
#    Valeurs uniques: 18
#    Valeurs: [nan, 'détaché', 'à étages, détaché', 'à étages, jumelé', 'plain-pied, détaché', 'à un étage et demi, détaché', 'plain-pied', 'paliers multiples, détaché', 'à étages, en rangée', 'plain-pied, jumelé', 'à étages', 'en rangée', 'jumelé', 'paliers multiples, jumelé', 'plain-pied, en rangée', 'paliers multiples', 'paliers multiples, en rangée', 'à un étage et demi, jumelé', 'à un étage et demi, en rangée']
#
# 📊 Variable 'basement':
#    Valeurs uniques: 547
#    Valeurs: [nan, 'Sous-sol 6 pieds +', 'Sous-sol 6 pieds +, À proximité du REM', "Bord d'un lac, Plan d'eau navigable, Sous-sol 6 pieds +", "Bord d'un canal, Sous-sol 6 pieds +", "Accès à une rivière, Plan d'eau navigable, Sous-sol 6 pieds +", "Bord d'une rivière, Plan d'eau navigable, Sous-sol 6 pieds +", 'Borne de recharge pour véhicule, Cour privée, Sous-sol 6 pieds +', 'Ascenseur, Cour privée, Balcon privé, Sous-sol 6 pieds +', 'Cour privée, Sous-sol 6 pieds +', 'Accès à un lac, Sous-sol 6 pieds +', "Bord d'un lac, Plan d'eau navigable, Animaux acceptés, Sous-sol 6 pieds +", "Salle d'entraînement, Sous-sol 6 pieds +", "Plan d'eau navigable, Animaux acceptés, Ascenseur, Sous-sol 6 pieds +", 'Animaux acceptés, Cour privée, Sous-sol 6 pieds +', "Accès à un lac, Plan d'eau navigable, Sous-sol 6 pieds +", "Bord d'une rivière, Sous-sol 6 pieds +", "Bord d'un lac, Accès à un canal, Plan d'eau navigable, Sous-sol 6 pieds +", "Bord d'une rivière, Plan d'eau navigable, Sous-sol 6 pieds +, À proximité du REM", "Bord d'une rivière, Plan d'eau non navigable, Sous-sol 6 pieds +", 'Cour privée, Balcon privé, Sous-sol 6 pieds +', "Accès à une rivière, Plan d'eau non navigable, Sous-sol 6 pieds +", "Bord d'un lac, Plan d'eau navigable, Cour privée, Sous-sol 6 pieds +", "Bord d'un ruisseau, Plan d'eau non navigable, Sous-sol 6 pieds +", 'Balcon privé, Sous-sol 6 pieds +', "Bord d'un lac, Sous-sol 6 pieds +", "Bord d'un fleuve, Plan d'eau navigable, Sous-sol 6 pieds +", "Bord d'un fleuve, Accès à un ruisseau, Plan d'eau navigable, Sous-sol 6 pieds +", 'Ascenseur, Sous-sol 6 pieds +, À proximité du REM', 'Animaux acceptés, Sous-sol 6 pieds +', "Bord d'un lac, Plan d'eau navigable, Cour privée, Balcon privé, Sous-sol 6 pieds +", "Accès à un lac, Plan d'eau navigable, Cour privée, Sous-sol 6 pieds +", 'Accès à un étang, Animaux acceptés, Cour privée, Sous-sol 6 pieds +', 'Chats acceptés, Sous-sol 6 pieds +', "Accès à un canal, Plan d'eau navigable, Borne de recharge pour véhicule, Sous-sol 6 pieds +", "Accès à un lac, Plan d'eau navigable, Borne de recharge pour véhicule, Sous-sol 6 pieds +", "Bord d'un canal, Plan d'eau navigable, Sous-sol 6 pieds +", 'Reprise de finance, Sous-sol 6 pieds +', 'Accès à un lac, Borne de recharge pour véhicule, Sous-sol 6 pieds +', 'Villégiature, Sous-sol 6 pieds +', "Bord d'un réservoir, Plan d'eau navigable, Sous-sol 6 pieds +", "Accès à un lac, Plan d'eau non navigable, Sous-sol 6 pieds +", 'Ascenseur, Cour privée, Sous-sol 6 pieds +', "Bord d'un lac, Plan d'eau navigable, Balcon privé, Sous-sol 6 pieds +", 'Accès à une rivière, Sous-sol 6 pieds +', "Bord d'une rivière, Plan d'eau navigable, Cour privée, Balcon privé, Sous-sol 6 pieds +", "Bord d'un lac, Plan d'eau non navigable, Sous-sol 6 pieds +", "Bord d'un fleuve, Chats acceptés, Chiens acceptés, Balcon privé, Sous-sol 6 pieds +, À proximité du REM", 'Fumeurs acceptés, Sous-sol 6 pieds +, À proximité du REM', "Bord d'un lac, Cour privée, Balcon privé, Sous-sol 6 pieds +", 'Ascenseur, Sous-sol 6 pieds +', "Plan d'eau navigable, Ascenseur, Sous-sol 6 pieds +", "Bord d'un fleuve, Ascenseur, Sous-sol 6 pieds +", 'Animaux acceptés, Cour privée, Balcon privé, Sous-sol 6 pieds +', 'Borne de recharge pour véhicule, Sous-sol 6 pieds +', "Bord d'un étang, Accès à un lac, Villégiature, Animaux acceptés, Balcon privé, Sous-sol 6 pieds +", 'Ascenseur, Borne de recharge pour véhicule, Sous-sol 6 pieds +', 'Cour privée, Sous-sol 6 pieds +, À proximité du REM', 'Fumeurs non acceptés, Sous-sol 6 pieds +', 'Animaux acceptés, Balcon privé, Sous-sol 6 pieds +', "Ascenseur, Balcon privé, Salle d'entraînement, Sous-sol 6 pieds +", "Plan d'eau navigable, Animaux non acceptés, Fumeurs non acceptés, Ascenseur, Sous-sol 6 pieds +", 'Villégiature, Animaux acceptés, Sous-sol 6 pieds +', "Accès à un lac, Plan d'eau navigable, Plan d'eau non navigable, Cour privée, Sous-sol 6 pieds +", 'Saisonnier, Sous-sol 6 pieds +', "Bord d'un lac, Plan d'eau non navigable, Balcon privé, Sous-sol  ...
#
# 📊 Variable 'type_id':
#    Valeurs uniques: 1
#    Valeurs: ['unknown']
#                                              city                plex-revenue  \
# 0  Montréal (Côte-Des-Neiges/Notre-Dame-De-Grâce)  Rev. bruts pot. : 26 100 $
# 1                                         Chambly                         NaN
# 2                                         Chambly                         NaN
# 3                                         Chambly                         NaN
# 4                                         Chambly                         NaN
#
#       price     type  revenu  surface  longitude   latitude  price_assessment  \
# 0  749000.0  unknown     NaN      NaN        NaN        NaN               NaN
# 1  574900.0  unknown     NaN      NaN -73.292301  45.430607               NaN
# 2  448800.0  unknown     NaN   1266.0 -73.297033  45.432642          361000.0
# 3  519900.0  unknown     NaN      NaN -73.287130  45.442001               NaN
# 4  848500.0  unknown     NaN   3922.0 -73.322884  45.434597               NaN
#
#   region  ...  municipal_evaluation_land  municipal_evaluation_total  \
# 0    NaN  ...                        NaN                         NaN
# 1    NaN  ...                        NaN                         NaN
# 2    NaN  ...                        NaN                         NaN
# 3    NaN  ...                        NaN                         NaN
# 4    NaN  ...                        NaN                         NaN
#
#   municipal_evaluation_year  municipal_tax  school_tax  year_built  \
# 0                       NaN            NaN         NaN         NaN
# 1                       NaN            NaN         NaN         NaN
# 2                       NaN            NaN         NaN         NaN
# 3                       NaN            NaN         NaN         NaN
# 4                       NaN            NaN         NaN         NaN
#
#    living_area  water_rooms  basement  type_id
# 0          NaN          NaN       NaN  unknown
# 1          NaN          NaN       NaN  unknown
# 2          NaN          NaN       NaN  unknown
# 3          NaN          NaN       NaN  unknown
# 4          NaN          NaN       NaN  unknown
#
# [5 rows x 25 columns]

# %% [raw]
# ## 🔢 ÉTAPE 3: Encodage des Variables

# %%
# Encoder les variables catégorielles
df_step3 = analyzer.step_3_encode_features(df_step2)

print("\n🔍 Vérification après encodage:")
print(f"Nouvelles colonnes: {list(df_step3.columns)}")
print(f"Types de données après encodage:")
print(df_step3.dtypes)

df_step3.head()

# %% [raw]
# ## 🔧 ÉTAPE 4: Imputation des Valeurs Manquantes

# %%
# Imputer les valeurs manquantes
df_step4 = analyzer.step_4_impute_missing_values(df_step3)

print("\n🔍 Vérification après imputation:")
print(f"Valeurs manquantes restantes: {df_step4.isnull().sum().sum()}")
print(f"Statistiques des colonnes imputées:")
print(df_step4.describe())

df_step4.head()

# %% [raw]
# ## 🏠 ÉTAPE 5: Classification des Propriétés

# %%
# Classifier les propriétés
df_step5 = analyzer.step_5_classify_properties(df_step4)

print("\n🔍 Vérification de la classification:")
print(f"Nouvelle colonne: 'classification_immobiliere'")
print(f"Distribution des classifications:")
print(df_step5['classification_immobiliere'].value_counts())

# Visualiser la distribution des prix par classification
print("\n💰 Prix moyen par catégorie:")
price_by_class = df_step5.groupby('classification_immobiliere')['price'].agg(['mean', 'median', 'count'])
print(price_by_class)

df_step5.head()

# %% [raw]
# ## 🎯 ÉTAPE 6: Préparation pour la Modélisation

# %%
# Préparer les données pour la modélisation
X, y = analyzer.step_6_prepare_for_modeling(df_step5, target_column='price')

print("\n🔍 Vérification des données préparées:")
print(f"Features (X): {X.shape}")
print(f"Target (y): {y.shape}")
print(f"\nColonnes features:")
for i, col in enumerate(X.columns, 1):
    print(f"  {i}. {col}")

print(f"\nStatistiques de la variable cible:")
print(y.describe())

X.head()

# %% [raw]
# ## 🎯 ÉTAPE 7: Sélection de Variables

# %%
# Sélectionner les variables importantes
selected_features = analyzer.step_7_select_features(X, y)

print("\n🔍 Analyse des variables sélectionnées:")
print(f"Variables sélectionnées: {selected_features}")

# Créer un sous-ensemble avec seulement les variables sélectionnées
X_selected = X[selected_features]
print(f"\nNouveaux features (X_selected): {X_selected.shape}")

X_selected.head()

# %% [raw]
# ## 🏠 ÉTAPE 8: Sélection par Type de Propriété

# %%
# Sélectionner les variables par type de propriété
classification_features = analyzer.step_8_select_by_classification(
    X, y, df_step5['classification_immobiliere']
)

print("\n🔍 Analyse des variables par type:")
if classification_features:
    for prop_type, features in classification_features.items():
        print(f"\n🏷️ {prop_type}:")
        print(f"   Variables importantes: {features}")
        
        # Créer un sous-ensemble pour ce type
        mask = df_step5['classification_immobiliere'] == prop_type
        X_type = X[mask][features]
        y_type = y[mask]
        print(f"   Données pour ce type: X={X_type.shape}, y={y_type.shape}")
else:
    print("Pas de sélection spécifique par type disponible")

# %% [raw]
# ## 📊 ÉTAPE 9: Importance des Variables

# %%
# Calculer l'importance des variables
feature_importance = analyzer.step_9_calculate_feature_importance(X, y)

print("\n🔍 Analyse détaillée de l'importance:")
importance_df = pd.DataFrame([
    {'feature': feature, 'importance': importance}
    for feature, importance in feature_importance.items()
]).sort_values('importance', ascending=False)

print("\n📊 Tableau d'importance complet:")
print(importance_df)

# Visualisation simple
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
top_features = importance_df.head(10)
plt.barh(range(len(top_features)), top_features['importance'])
plt.yticks(range(len(top_features)), top_features['feature'])
plt.xlabel('Importance')
plt.title('Top 10 Variables les Plus Importantes')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [raw]
# ## 🏆 ÉTAPE 10: Résumé Final

# %%
# Générer le résumé final
final_results = analyzer.step_10_final_summary()

print("\n📋 Résultats structurés:")
print(f"Résultats disponibles: {final_results.keys()}")

# Créer un DataFrame de résumé
summary_data = {
    'Métrique': [
        'Lignes originales',
        'Lignes après traitement',
        'Colonnes originales',
        'Colonnes après traitement',
        'Variables sélectionnées',
        'Taux de conservation des variables'
    ],
    'Valeur': [
        final_results.get('shape_original', (0, 0))[0],
        final_results.get('shape_processed', (0, 0))[0],
        final_results.get('shape_original', (0, 0))[1],
        final_results.get('shape_processed', (0, 0))[1],
        len(final_results.get('selected_features', [])),
        f"{(len(final_results.get('selected_features', [])) / (final_results.get('shape_processed', (0, 1))[1] - 1) * 100):.1f}%"
    ]
}

summary_df = pd.DataFrame(summary_data)
print("\n📊 Tableau de résumé:")
print(summary_df.to_string(index=False))

# %% [raw]
# ## 🚀 Utilisation pour la Modélisation

# %%
# Maintenant vous avez toutes les données prêtes pour la modélisation
print("🎯 Données prêtes pour la modélisation:")
print(f"\n📊 X (features complètes): {X.shape}")
print(f"📊 X_selected (features sélectionnées): {X_selected.shape}")
print(f"🎯 y (target): {y.shape}")
print(f"🏠 df_step5 (données complètes avec classification): {df_step5.shape}")

print(f"\n✅ Variables sélectionnées pour la modélisation:")
for i, feature in enumerate(selected_features, 1):
    print(f"  {i}. {feature}")

print(f"\n🏷️ Classifications disponibles:")
for category, stats in final_results.get('classification_stats', {}).get('counts', {}).items():
    print(f"  • {category}: {stats} propriétés")

print("\n🎉 Prêt pour l'entraînement de modèles!")

# %% [raw]
# ## 📝 Notes et Prochaines Étapes
#
# ### Données Disponibles:
# - `X`: Matrice complète des features
# - `X_selected`: Matrice avec seulement les features sélectionnées
# - `y`: Vecteur target (prix)
# - `df_step5`: DataFrame complet avec classification
# - `selected_features`: Liste des variables importantes
# - `classification_features`: Variables par type de propriété
# - `feature_importance`: Importance de chaque variable
#
# ### Prochaines Étapes:
# 1. **Séparation train/test**: `train_test_split(X_selected, y)`
# 2. **Entraînement de modèles**: RandomForest, XGBoost, etc.
# 3. **Validation croisée**: Pour évaluer la performance
# 4. **Optimisation des hyperparamètres**: GridSearch ou RandomSearch
# 5. **Évaluation finale**: Métriques de performance
#
# ### Avantages de cette Approche:
# - ✅ Contrôle total sur chaque étape
# - ✅ Debugging facile
# - ✅ Possibilité d'ajuster chaque étape individuellement
# - ✅ Visualisation des résultats intermédiaires
# - ✅ Réutilisation des données traitées
#
# ### Utilisation Alternative - Analyse Complète:
# ```python
# # Si vous voulez exécuter tout d'un coup (comme avant)
# analyzer = PropertyAnalyzer()
# results = analyzer.analyze_properties(df, target_column='price')
# ```
